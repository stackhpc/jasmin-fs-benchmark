# %%
# This just dumps all results into a csv

import pandas as pd
import glob, os
import read_summary

# Create a dataframe and units dict from any result summary files found:
pattern = './runs/*/result_summary.txt'
results, units = read_summary.df_from_pattern(pattern)
print('Loaded %i result files.' % len(results))
print('Columns/units:')
print(units)
print()
results.to_csv('all-results.csv')
# Out:
# loading ./runs/panasas-1-1-300-0-POSIX/result_summary.txt
# loading ./runs/panasas-1-2-300-0-POSIX/result_summary.txt
# loading ./runs/quobyte-1-1-300-0-POSIX/result_summary.txt
# loading ./runs/quobyte-1-2-300-0-POSIX/result_summary.txt
# loading ./runs/panasas-1-4-300-0-POSIX/result_summary.txt
# loading ./runs/quobyte-1-4-300-0-POSIX/result_summary.txt
# loading ./runs/panasas-1-16-300-0-POSIX/result_summary.txt
# loading ./runs/quobyte-1-16-300-0-POSIX/result_summary.txt
# loading ./runs/panasas-2-2-300-0-POSIX/result_summary.txt
# loading ./runs/quobyte-2-2-300-0-POSIX/result_summary.txt
# loading ./runs/panasas-10-2-300-0-POSIX/result_summary.txt
# loading ./runs/quobyte-10-2-300-0-POSIX/result_summary.txt
# loading ./runs/panasas-1-1-300-1-POSIX/result_summary.txt
# loading ./runs/panasas-1-1-300-2-POSIX/result_summary.txt
# loading ./runs/quobyte-1-1-300-1-POSIX/result_summary.txt
# loading ./runs/quobyte-1-1-300-2-POSIX/result_summary.txt
# loading ./runs/panasas-1-2-300-1-POSIX/result_summary.txt
# loading ./runs/panasas-1-2-300-2-POSIX/result_summary.txt
# loading ./runs/quobyte-1-2-300-1-POSIX/result_summary.txt
# loading ./runs/quobyte-1-2-300-2-POSIX/result_summary.txt
# loading ./runs/panasas-1-4-300-1-POSIX/result_summary.txt
# loading ./runs/panasas-1-4-300-2-POSIX/result_summary.txt
# loading ./runs/quobyte-1-4-300-1-POSIX/result_summary.txt
# loading ./runs/quobyte-1-4-300-2-POSIX/result_summary.txt
# loading ./runs/panasas-1-16-300-1-POSIX/result_summary.txt
# loading ./runs/panasas-1-16-300-2-POSIX/result_summary.txt
# loading ./runs/quobyte-1-16-300-1-POSIX/result_summary.txt
# loading ./runs/quobyte-1-16-300-2-POSIX/result_summary.txt
# loading ./runs/panasas-2-2-300-1-POSIX/result_summary.txt
# loading ./runs/panasas-2-2-300-2-POSIX/result_summary.txt
# loading ./runs/quobyte-2-2-300-1-POSIX/result_summary.txt
# loading ./runs/quobyte-2-2-300-2-POSIX/result_summary.txt
# loading ./runs/panasas-10-2-300-1-POSIX/result_summary.txt
# loading ./runs/panasas-10-2-300-2-POSIX/result_summary.txt
# loading ./runs/pure-1-1-300-0-POSIX/result_summary.txt
# loading ./runs/pure-1-1-300-1-POSIX/result_summary.txt
# loading ./runs/pure-1-1-300-2-POSIX/result_summary.txt
# loading ./runs/pure-1-2-300-0-POSIX/result_summary.txt
# loading ./runs/pure-1-2-300-1-POSIX/result_summary.txt
# loading ./runs/pure-1-2-300-2-POSIX/result_summary.txt
# loading ./runs/pure-1-4-300-0-POSIX/result_summary.txt
# loading ./runs/pure-1-4-300-1-POSIX/result_summary.txt
# loading ./runs/pure-1-4-300-2-POSIX/result_summary.txt
# loading ./runs/pure-1-16-300-0-POSIX/result_summary.txt
# loading ./runs/pure-1-16-300-1-POSIX/result_summary.txt
# loading ./runs/pure-1-16-300-2-POSIX/result_summary.txt
# loading ./runs/pure-2-2-300-0-POSIX/result_summary.txt
# loading ./runs/pure-2-2-300-1-POSIX/result_summary.txt
# loading ./runs/pure-2-2-300-2-POSIX/result_summary.txt
# loading ./runs/panasas-1-1-300-0-MPIIO/result_summary.txt
# loading ./runs/panasas-1-1-300-1-MPIIO/result_summary.txt
# loading ./runs/panasas-1-1-300-2-MPIIO/result_summary.txt
# loading ./runs/panasas-1-2-300-0-MPIIO/result_summary.txt
# loading ./runs/panasas-1-2-300-1-MPIIO/result_summary.txt
# loading ./runs/panasas-1-2-300-2-MPIIO/result_summary.txt
# loading ./runs/panasas-1-4-300-0-MPIIO/result_summary.txt
# loading ./runs/panasas-1-4-300-1-MPIIO/result_summary.txt
# loading ./runs/panasas-1-16-300-0-MPIIO/result_summary.txt
# loading ./runs/panasas-1-16-300-1-MPIIO/result_summary.txt
# loading ./runs/panasas-1-16-300-2-MPIIO/result_summary.txt
# loading ./runs/panasas-2-2-300-0-MPIIO/result_summary.txt
# loading ./runs/panasas-2-2-300-1-MPIIO/result_summary.txt
# loading ./runs/panasas-2-2-300-2-MPIIO/result_summary.txt
# loading ./runs/panasas-1-32-300-0-POSIX/result_summary.txt
# loading ./runs/panasas-1-32-300-1-POSIX/result_summary.txt
# loading ./runs/panasas-1-32-300-2-POSIX/result_summary.txt
# loading ./runs/pure-1-32-300-0-POSIX/result_summary.txt
# loading ./runs/pure-1-32-300-1-POSIX/result_summary.txt
# loading ./runs/pure-1-32-300-2-POSIX/result_summary.txt
# loading ./runs/panasas-2-1-300-0-POSIX/result_summary.txt
# loading ./runs/panasas-2-1-300-1-POSIX/result_summary.txt
# loading ./runs/panasas-2-1-300-2-POSIX/result_summary.txt
# loading ./runs/pure-2-1-300-0-POSIX/result_summary.txt
# loading ./runs/pure-2-1-300-1-POSIX/result_summary.txt
# loading ./runs/pure-2-1-300-2-POSIX/result_summary.txt
# loading ./runs/panasas-2-16-300-0-POSIX/result_summary.txt
# loading ./runs/panasas-2-16-300-1-POSIX/result_summary.txt
# loading ./runs/pure-2-16-300-0-POSIX/result_summary.txt
# loading ./runs/pure-2-16-300-1-POSIX/result_summary.txt
# loading ./runs/pure-2-16-300-2-POSIX/result_summary.txt
# loading ./runs/quobyte-1-32-300-0-POSIX/result_summary.txt
# loading ./runs/quobyte-1-32-300-2-POSIX/result_summary.txt
# loading ./runs/quobyte-2-16-300-0-POSIX/result_summary.txt
# loading ./runs/quobyte-2-16-300-1-POSIX/result_summary.txt
# loading ./runs/quobyte-2-16-300-2-POSIX/result_summary.txt
# loading ./runs/pure-1-2-300-0-MPIIO/result_summary.txt
# loading ./runs/pure-1-2-300-1-MPIIO/result_summary.txt
# loading ./runs/pure-1-2-300-2-MPIIO/result_summary.txt
# loading ./runs/pure-1-16-300-0-MPIIO/result_summary.txt
# loading ./runs/pure-1-16-300-1-MPIIO/result_summary.txt
# loading ./runs/pure-1-16-300-2-MPIIO/result_summary.txt
# loading ./runs/panasas-2-16-300-0-MPIIO/result_summary.txt
# loading ./runs/panasas-2-16-300-2-MPIIO/result_summary.txt
# loading ./runs/pure-2-2-300-0-MPIIO/result_summary.txt
# loading ./runs/pure-2-2-300-1-MPIIO/result_summary.txt
# loading ./runs/pure-2-2-300-2-MPIIO/result_summary.txt
# loading ./runs/pure-2-16-300-0-MPIIO/result_summary.txt
# loading ./runs/pure-2-16-300-1-MPIIO/result_summary.txt
# loading ./runs/pure-2-16-300-2-MPIIO/result_summary.txt
# loading ./runs/pure-10-2-300-0-POSIX/result_summary.txt
# loading ./runs/panasas-10-16-300-0-POSIX/result_summary.txt
# loading ./runs/pure-10-16-300-0-POSIX/result_summary.txt
# loading ./runs/pure-10-2-300-1-POSIX/result_summary.txt
# loading ./runs/pure-10-2-300-2-POSIX/result_summary.txt
# loading ./runs/pureblock-1-1-30-0-POSIX/result_summary.txt
# loading ./runs/pureblock-1-2-30-0-POSIX/result_summary.txt
# loading ./runs/pureblock-1-4-30-0-POSIX/result_summary.txt
# loading ./runs/pureblock-1-8-30-0-POSIX/result_summary.txt
# Loaded 108 result files.
# Columns/units:
# {'nodes': None, 'ntasks_per_node': None, 'filesystem.name': None, 'filesystem.mountpoint': None, 'stonewall': None, 'iters': None, 'time': None, 'ior_api': None, 'ior-easy-write': 'GiB/s', 'mdtest-easy-write': 'kIOPS', 'ior-hard-write': 'GiB/s', 'mdtest-hard-write': 'kIOPS', 'find': 'kIOPS', 'ior-easy-read': 'GiB/s', 'mdtest-easy-stat': 'kIOPS', 'ior-hard-read': 'GiB/s', 'mdtest-hard-stat': 'kIOPS', 'mdtest-easy-delete': 'kIOPS', 'mdtest-hard-read': 'kIOPS', 'mdtest-hard-delete': 'kIOPS', 'bandwidth-score': 'GiB/s', 'iops-score': 'kiops', 'total-score': None}
