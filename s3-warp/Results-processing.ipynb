# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Pure" data-toc-modified-id="Pure-1">Pure</a></span></li><li><span><a href="#Quobyte" data-toc-modified-id="Quobyte-2">Quobyte</a></span></li><li><span><a href="#Caringo" data-toc-modified-id="Caringo-3">Caringo</a></span><ul class="toc-item"><li><span><a href="#Pure-Storage" data-toc-modified-id="Pure-Storage-3.1">Pure Storage</a></span></li><li><span><a href="#Quobyte" data-toc-modified-id="Quobyte-3.2">Quobyte</a></span></li><li><span><a href="#Caringo" data-toc-modified-id="Caringo-3.3">Caringo</a></span></li></ul></li><li><span><a href="#Vendor-comparison-plots" data-toc-modified-id="Vendor-comparison-plots-4">Vendor comparison plots</a></span></li><li><span><a href="#Missing-Quobyte-data-investigation" data-toc-modified-id="Missing-Quobyte-data-investigation-5">Missing Quobyte data investigation</a></span><ul class="toc-item"><li><span><a href="#Exceptionally-slow-requests" data-toc-modified-id="Exceptionally-slow-requests-5.1">Exceptionally slow requests</a></span></li></ul></li></ul></div>

# %%
# Imports and function defs 
import os
import re
import pathlib
import logging
import itertools
import datetime as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Set some default plotting properties
import matplotlib as mpl
mpl.rcParams['savefig.dpi'] = 1000
mpl.rcParams['font.family'] = "Arial"

# Make figures dir
if not pathlib.Path('./figures').exists():
    os.mkdir('./figures')

# Define some useful function

def GiB_to_Gb(val):
    return val*8*1024**3/10**9

def Gb_to_GiB(val):
    return val*10**9/(8*1024**3)

def file_filter(file, vendor, op, nodes, threads, obj_size):
    pattern = re.compile(f's3-summary.{vendor}-{op}-{nodes}-{threads}-{obj_size}-.*s\.')
    return (re.match(pattern, file.name) is not None and file.suffix == '.txt')

def parse_node_and_thread_count(filename: str):
    """Parses thread and node counts from results file name"""
    node_pattern = re.compile(r'\.[a-zA-Z0-9]+-[a-zA-Z]+-[1-9][0-9]*-')
    nodes = int(re.search(node_pattern, filename).group().split('-')[-2])
    thread_pattern = re.compile(r'-[1-9][0-9]*-[1-9][0-9]*[KMG]iB')
    threads = int(re.search(thread_pattern, filename).group().split('-')[1])
    return nodes, threads

def check_data_sanity(df, op, filename=None):
    """
    Checks various aspects of the given results dataframe of raw warp results
    Provide an optional filename to be included in warning messages.
    """
    data = df[df.op == op]
    groups = data.groupby('thread')
    window_start =  groups.end.first().max()
    window_end = groups.start.last().min()
    window = window_end - window_start
    if window_start > window_end:
        msg = f'No useable analysis time window for {op} requests'
        #Check if it was due to single-request threads
        threads = len(groups)
        threads_single_request = sum(groups.start.count() < 2)
        if threads_single_request > 0:
            msg += ' (some threads completed only 1 request)'
        if filename:
            msg += '\n File: ' + filename
        logging.warning(msg)
    # Check expected thread count matches data
    if filename:
        n, t = parse_node_and_thread_count(filename)
        if len(groups) != n*t:
            logging.warning(
                f"Benchmark data for {op} requests only contains {len(groups)} threads, expected {n*t}.\n File: {filename}"
            )
    
    return {
        'total_upload_time': data.end.max() - data.start.min(),
        'useable_window': window if window_start < window_end else pd.Timedelta(0),
    }

def load_raw_data(results_file, check_error=True, sanity_checks=True):
    """Load and preprocess raw benchmark data from `warp`"""
    # Use low_memory kwarg to supress mixed dtype warnings from pandas
    df = pd.read_csv(results_file, sep="\t", low_memory=False)
    # Separate out benchmark command
    warp_command = df.iloc[-1].idx
    df = df.iloc[:-1]
    # Drop some unused columns
    df = df.drop(['idx'], axis=1)
    if check_error:
        if df.error.isna().all():
            df = df.drop('error', axis=1)
        else:
            raise Exception("Errors found in df.error column")
    if df.n_objects.eq(1).all():
        df = df.drop('n_objects', axis=1)
    # Convert some data dtypes
    for col in ['start', 'end']:
#         df[col] = df[col].map(parse_datetime)    
        df[col] = pd.to_datetime(df[col])
    # Do some additional sanity_checks
    if sanity_checks:
        for op in df.op.unique():
            check_data_sanity(df, op, filename=results_file)

    return df, warp_command

def load_summary_data(filename):
    """Loads the summary csv data from `warp analyze ...` into a pandas dataframe"""
    df = pd.read_csv(filename, sep="\t")
    df = df[~(df.op == "op")]
    for col in ['mb_per_sec', 'objs_per_sec']:
        df[col] = pd.to_numeric(df[col])
    return df

def parse_text_summary(filename):
    """Parses the text summary from `warp analyze ...` and generates a dict of throughput values"""
    # Read input and compile reusable regexs
    op_regex = re.compile(r"[A-Z][A-Z]+")
    score_regex = re.compile(r"[0-9]+\.[0-9]+\ [a-zA-Z]+/s")
    with open(filename, "r") as file:
        lines = file.readlines()
    # Iterate through file lines and extract relevant pieces
    scores = {}
    current_op = None
    for line in lines:
        if line.startswith("Operation: "):
            op = op_regex.search(line)[0]
            current_op = op
            scores[op] = {}
        elif line.startswith(" * Throughput: ") or line.startswith("* Average:"):
            for score in score_regex.finditer(line):
                val, unit = score[0].split(" ")
                scores[current_op][unit] = float(val)
        elif line.startswith("Cluster Total: "):
            scores["Total"] = {}
            for score in score_regex.finditer(line):
                val, unit = score[0].split(" ")
                scores["Total"][unit] = float(val)
    # Convert MiB/s to GiB/s and obj/s to kIOPS
    for op in scores.keys():
        if 'obj/s' in scores[op].keys():
            val = scores[op].pop('obj/s')
            scores[op]['kIOPS'] = val / 1000
        if 'MiB/s' in scores[op].keys():
            val = scores[op].pop('MiB/s')
            scores[op]['GiB/s'] = val / 1024
        
    return scores

def process_results(
    data_dir, 
    filter_func,
    vendors=['pure', 'quobyte', 'caringo'],
    nodes = [1, 2, 5],
    threads = [1, 20, 50, 100],
    sizes = ['10KiB', '10MiB', '100MiB', '1GiB'],
    ops = ['get', 'put'],
    units = ['GiB/s', 'kIOPS'],
    sanity_checks=False,
):
    
    # Load scores
#     print(list(itertools.product(vendors, nodes, threads, sizes)))
    all_scores = []
    for v, n, t in itertools.product(vendors, nodes, threads):



        for s in sizes:
            
            # Always use 'get' as op in filter since this file also holds 'put' scores
            files = list(filter(
                lambda f: file_filter(f, v, 'get', n, t, s),
                data_dir.iterdir()
            ))
            if len(files) > 1:
                raise Exception(
                    f'Ambiguous file filter - {len(files)} files found for:',
                    v, 'get', n, t, s,
                    '\nFiles:', files
                )
            f = files[0]

            try:
                
                # Load raw data to trigger sanity checks
                if sanity_checks:
                    raw_data_f = f.name.replace('.txt', '.csv.zst').replace('summary', 'full')
                    path = f.parent.parent.joinpath('../raw-data/').joinpath(raw_data_f)
                    load_raw_data(path.as_posix(), sanity_checks=True)

                # Load scores from summary file
                scores = parse_text_summary(files[0])

            except Exception as e:                            
                if isinstance(e, FileNotFoundError):
                    logging.warning(e)
                else:
                    raise e

            for op in ops:
                try:
                    # Create data record
                    data = {}
                    data['vendor'] = v
                    data['nodes'] = n
                    data['threads'] = t
                    data['obj_size'] = s
                    data['operation'] = op
                    data[f'Throughput (GiB/s)'] = scores[op.upper()]['GiB/s']
                    data['kIOPS'] = scores[op.upper()]['kIOPS']
                except KeyError:
                    logging.warning(f"Missing '{op}' data in file {f}")

                all_scores.append(data)
                    
    df = pd.DataFrame.from_records(all_scores)
    numeric_cols = ['nodes', 'threads', 'Throughput (GiB/s)', 'kIOPS']
    df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric)
    return df


def expand_col(df, idxs, cat_col, val_col):
    df = df.set_index(idxs)
    mask = pd.get_dummies(df[cat_col])
    result = mask.mul(df[val_col], axis=0).groupby(idxs).max()
    result.replace(0, np.nan, inplace=True)
    return result


def label_axes(ax, df, ylabel):
    nodes_and_threads = df.index.unique().values
    xlabels = [f'{n}-N\n{t}-T' for n, t in nodes_and_threads]
    ax.set_xticklabels(xlabels, rotation=0)
    ax.set_xlabel('Nodes (N) & Tasks-per-node (T)')
    ax.set_ylabel(ylabel)
    if 'GiB/s' in ylabel:
        ax2 = ax.twinx()
        ax2.set_ylim(tuple(map(GiB_to_Gb, ax.get_ylim())))
        ax2.set_ylabel('Gb/s')
    return ax


results_df = process_results(
    pathlib.Path('./benchmark-runs/summaries/txt/'),
    file_filter,
)
results_df.to_csv('s3-all-results.csv')
results_df
# Out:
# WARNING:root:Missing 'get' data in file benchmark-runs/summaries/txt/s3-summary.quobyte-get-2-50-1GiB-5000-300s.txt
# WARNING:root:Missing 'put' data in file benchmark-runs/summaries/txt/s3-summary.quobyte-get-2-50-1GiB-5000-300s.txt
# WARNING:root:Missing 'put' data in file benchmark-runs/summaries/txt/s3-summary.quobyte-get-2-100-1GiB-5000-300s.txt
# WARNING:root:Missing 'get' data in file benchmark-runs/summaries/txt/s3-summary.quobyte-get-5-20-1GiB-1000-60s.txt
# WARNING:root:Missing 'get' data in file benchmark-runs/summaries/txt/s3-summary.quobyte-get-5-50-1GiB-1000-60s.txt
# WARNING:root:Missing 'put' data in file benchmark-runs/summaries/txt/s3-summary.quobyte-get-5-50-1GiB-1000-60s.txt
# WARNING:root:Missing 'get' data in file benchmark-runs/summaries/txt/s3-summary.quobyte-get-5-100-1GiB-5000-300s.txt
# WARNING:root:Missing 'put' data in file benchmark-runs/summaries/txt/s3-summary.quobyte-get-5-100-1GiB-5000-300s.txt
# ...

# %% [markdown]
# Check for any missing data:

# %%
results_df[(results_df.kIOPS.isna()) | (results_df['Throughput (GiB/s)'].isna())]
# Out:
#       vendor  nodes  threads obj_size operation  Throughput (GiB/s)  kIOPS
# 150  quobyte      2       50     1GiB       get                 NaN    NaN
# 151  quobyte      2       50     1GiB       put                 NaN    NaN
# 159  quobyte      2      100     1GiB       put                 NaN    NaN
# 174  quobyte      5       20     1GiB       get                 NaN    NaN
# 182  quobyte      5       50     1GiB       get                 NaN    NaN
# 183  quobyte      5       50     1GiB       put                 NaN    NaN
# 190  quobyte      5      100     1GiB       get                 NaN    NaN
# 191  quobyte      5      100     1GiB       put                 NaN    NaN
# 286  caringo      5      100     1GiB       get                 NaN    NaN

# %% [markdown]
# # Summary plots

# %% [markdown]
# ## Pure

# %% [markdown]
# Throughput:

# %%
# Code 
def plot_vendor_rw(
    df, 
    vendor, 
    score,
    ops = ['get', 'put'], 
    single_node_limit = True,
    highlight_missing = True,
    color = ["blue", "indigo", "slateblue", "mediumvioletred"],
    **kwargs
):
    
    fig, axs = plt.subplots(figsize=(7, 6), nrows=2)
#     fig.suptitle(f'{vendor.title()} storage - Object throughput')
    
    single_node_limit = single_node_limit and 'GiB' in score
    
    for i, (ax, op) in enumerate(zip(axs, ops)):
        # Separate scores into col per obj_size
        data = expand_col(
            df[(df.operation == op) & (df.vendor == vendor)],
            ['nodes', 'threads'],
            'obj_size',
            score,
        )
        # Make sure data is in correct order
        data = data[['10KiB', '10MiB', '100MiB', '1GiB']]
        any_missing = data.isna().any().any()

        # Plot data
        ax = data.plot.bar(color=color, legend=False, ax=ax, width=0.8, zorder=5, **kwargs)

        if single_node_limit:
            ax.axhline([Gb_to_GiB(50)], label='1-N limit (2x25 Gb/s)', c='grey', ls='--')
        if 'IOPS' in score:
            ax.set_yscale('log')
        
        if highlight_missing:
            ylims = ax.get_ylim()
            data.fillna(100*data.max().max(), inplace=True)
            ax = data.plot.bar(color='grey', alpha=0.5, legend=False, ax=ax, width=0.8, zorder=4, **kwargs)
            ax.set_ylim(ylims)
            
        ax = label_axes(ax, data, score)
        ax.grid(axis='y')

        if i == 0:
            handles, labels = ax.get_legend_handles_labels()
            if highlight_missing:
                N = len(data.columns)
                new_handles = handles[:(N+single_node_limit)]
                new_labels = labels[:N+single_node_limit] 
                if any_missing:
                    new_handles += handles[-1]
                    new_labels += ['No data']
            ax.legend(new_handles, new_labels, title='Object size:', loc=2)
            
    return fig, axs

vendor = 'pure'
fig, axs = plot_vendor_rw(results_df, vendor, 'Throughput (GiB/s)')
axs[0].set_title(f'{vendor.title()} Object Store - Read (GET requests)')
axs[1].set_title(f'{vendor.title()} Object Store - Write (PUT requests)')
# fig.suptitle('Pure FlashBlade - Object throughput')
fig.tight_layout()
fig.savefig(f'figures/{vendor}-throughput-v2.png')

# %% [markdown]
# IOPS:

# %%
vendor = 'pure'
fig, axs = plot_vendor_rw(results_df, vendor, 'kIOPS')
axs[0].set_title(f'{vendor.title()} Object Store - Read (GET requests)')
axs[1].set_title(f'{vendor.title()} Object Store - Write (PUT requests)')
fig.tight_layout()
fig.savefig(f'figures/{vendor}-iops-v2.png')

# %% [markdown]
# ## Quobyte

# %% [markdown]
# Throughput:

# %%
vendor = 'quobyte'
fig, axs = plot_vendor_rw(results_df, vendor, 'Throughput (GiB/s)')
axs[0].set_title(f'{vendor.title()} Object Store - Read (GET requests)')
axs[1].set_title(f'{vendor.title()} Object Store - Write (PUT requests)')
fig.tight_layout()
fig.savefig(f'figures/{vendor}-throughput-v2.png')

# %% [markdown]
# IOPS:

# %%
vendor = 'quobyte'
fig, axs = plot_vendor_rw(results_df, vendor, 'kIOPS')
axs[0].set_title(f'{vendor.title()} Object Store - Read (GET requests)')
axs[1].set_title(f'{vendor.title()} Object Store - Write (PUT requests)')
fig.tight_layout()
fig.savefig(f'figures/{vendor}-iops-v2.png')

# %% [markdown]
# ## Caringo

# %%
vendor = 'caringo'
fig, axs = plot_vendor_rw(results_df, vendor, 'Throughput (GiB/s)')
axs[0].set_title(f'{vendor.title()} Object Store - Read (GET requests)')
axs[1].set_title(f'{vendor.title()} Object Store - Write (PUT requests)')
fig.tight_layout()
fig.savefig(f'figures/{vendor}-throughput-v2.png')

# %%
vendor = 'caringo'
fig, axs = plot_vendor_rw(results_df, vendor, 'kIOPS')
axs[0].set_title(f'{vendor.title()} Object Store - Read (GET requests)')
axs[1].set_title(f'{vendor.title()} Object Store - Write (PUT requests)')
fig.tight_layout()
fig.savefig(f'figures/{vendor}-iops-v2.png')

# %%
def plot_vendor_comparison(df, score, obj_size):
    
    _df = df[df.obj_size == obj_size]
    _df = expand_col(_df, ['operation', 'nodes', 'threads'], 'vendor', score)
    N = len(_df.columns)
    bar_width = 0.75
    
    fig, axs = plt.subplots(figsize=(7, 5), nrows=2, ncols=2)
    
    for ax, (n, t) in zip(axs.flatten(), [(1, 1), (1, 100), (2, 100), (5, 100)]):
        
        data = _df.loc[:, n, t]
        any_missing = data.isna().any().any()
        
        data.plot.bar(ax=ax, color='rgb', width=bar_width, legend=False, zorder=5)
        if 'iops' in score.lower():
            ax.set_yscale('log')

        # Hacky workaround to highlight missing data
        ylims = ax.get_ylim()
        _data = data.fillna(1000*data.max().max())
        ax = _data.plot.bar(ax=ax, alpha=0.5, color='grey', width=bar_width, legend=False, zorder=4)
        ax.set_ylim(ylims)
        
        if n == 1 and t == 1:
            handles, labels = ax.get_legend_handles_labels()
            new_handles = handles[:N+any_missing]
            new_labels = labels[:N]
            if any_missing:
                new_labels += ['No data']
            ax.legend(new_handles, new_labels, title="Object store:")

        title = f'{n}-Node' + ('s' if n > 1 else '')
        title += f' {t}-Thread' + ('s' if n > 1 else '')
        ax.set_title(title)
        ax.grid(axis='y')
        ax.set_xlabel('')
        ax.set_xticklabels(['Read', 'Write'], rotation=0)
        ax.set_ylabel('Throughput (GiB/s)')
        
    return fig, axs

fig, axs = plot_vendor_comparison(results_df, 'Throughput (GiB/s)', '1GiB')
fig.suptitle('Large object (1GiB) throughput comparison')
fig.tight_layout()
fig.savefig('figures/vendor-comparison-large-obj-throughput-v2.png')

# %%
fig, axs = plot_vendor_comparison(results_df, 'kIOPS', '10KiB')
fig.suptitle("Small object (10KiB) 'create' comparison")
fig.tight_layout()
fig.savefig('figures/vendor-comparison-create-iops-v2.png')
plt.show()

# %%
# Code 

def plot_single_vendor_summary(
    vendor, 
    op, 
    unit='GiB/s',
    ax=None,
    return_summary=True,
    legend=True,
    bar_colours=None,
    highlight_missing=True,
    sanity_checks=False,
    **legend_kwargs
):
            
    # Load scores
    data_dir = pathlib.Path('./benchmark-runs/summaries/txt/')
    scores = {}
    for nodes in [1, 2, 5]:
        for threads in [1, 20, 50, 100]:
            group_key = f'{nodes}-N\n{threads}-T'
            scores[group_key] = {}
            for size in ['10KiB', '10MiB', '100MiB', '1GiB']:
                # Always use 'get' as op filter since this file also holds 'put' scores
                files = list(filter(
                    lambda f: file_filter(f, vendor, 'get', nodes, threads, size),
                    data_dir.iterdir()
                ))
                if len(files) > 1:
                    raise Exception(
                        f'Ambiguous file filter - {len(files)} files found for:',
                        vendor, 'get', nodes, threads, size,
                        '\nFiles:', files
                    )
                try:
                    # Load raw data to trigger sanity checks
                    if sanity_checks:
                        raw_data_filename = files[0].name.replace('.txt', '.csv.zst').replace('summary', 'full')
                        raw_data_path = files[0].parent.parent.joinpath('../raw-data/').joinpath(raw_data_filename)
                        load_raw_data(raw_data_path.as_posix(), sanity_checks=True)
                    # Load scores from summary file
                    scores[group_key][size] = parse_text_summary(files[0])[op.upper()]
                except Exception as e:
                    if isinstance(e, FileNotFoundError):
                        logging.warning(e)
                    scores[group_key][size] = {'GiB/s': 0, 'kIOPS': 0}
                if unit not in scores[group_key][size].keys():
                    scores[group_key][size] = {unit: 0}  
    
    # Wrangle data into plottable format
    groups = list(scores.keys())
    keys = [k for k, v in scores[groups[0]].items() if unit in v.keys()]
    data = {k:[scores[g][k][unit] for g in groups] for k in keys}

    x = np.arange(len(groups))  # label locations
    width = 1 / (1+len(keys)) # width of the bars
    multiplier = (1.5 - len(keys)/2)
    
    if ax is None:
        fig, ax = plt.subplots(figsize=(8, 4), constrained_layout=True)
    ax.grid(axis="y", lw=0.5, zorder=0)
    
    missing_label_set = False
    for i, (k, d) in enumerate(data.items()):
        offset = width * multiplier
        rects = ax.bar(
            x + offset, 
            d, 
            width, 
            ec="k", 
            label=k, 
            zorder=3,
            color=(bar_colours[k] if bar_colours is not None else None)
        )
        multiplier += 1
        # Add temporary marker for missing data
        if highlight_missing:
            for i, s in enumerate(d):
                if s == 0:
                    L = 'Missing data' if not missing_label_set else ''
                    ax.axvline([i+offset], lw=5, c='grey', alpha=0.5, label=L)
                    missing_label_set = True

    # Add some extra stuff
#     ax.set_yscale('log')
    ax.set_xticks(x + width, groups)
    ax.set_ylabel(unit)
    
    if unit == 'GiB/s':
        ax.axhline([Gb_to_GiB(50)], label='1-N limit (2x25 Gb/s)', c='grey', ls='--')
        # Create second axis with Gb/s units
        ax2 = ax.twinx()
        ax2.set_ylim(tuple(map(GiB_to_Gb, ax.get_ylim())))
        ax2.set_ylabel('Gb/s')
#         ax2.set_yscale('log')

    if legend:
        ax.legend(title='Object size:', **legend_kwargs)
        
    if return_summary:
        max_serial = max([item[unit] for item in scores['1-N\n1-T'].values()])
        max_1N = max(
            max([item[unit] for item in scores[f'1-N\n{t}-T'].values()]) 
            for t in [1, 20, 50, 100]
        )
        max_parallel = max(
            max([
                max([item[unit] for item in scores[f'{n}-N\n{t}-T'].values()]) 
                for t in [1, 20, 50, 100]
            ]) for n in [1, 2, 5]
        )
        df = pd.DataFrame({
            f'single-node single-thread ({unit})': [max_serial],
            f'single-node multi-thread ({unit})': [max_1N],
            f'multi-node multi-thread ({unit})': [max_parallel],
        }, index=[f'Maximum {op.upper()} score'])
        
        return ax, df
        
    return ax

# %% [markdown]
# ### Pure Storage
#
# File size throughput:

# %%
# Code 
vendor = 'pure'
fig, axs = plt.subplots(figsize=(7, 6), nrows=2)
bar_colours = {"10KiB":"blue", "10MiB":"indigo", "100MiB":"slateblue", "1GiB":"mediumvioletred"}

axs[0].set_title('Read (GET requests)')
_, df_get = plot_single_vendor_summary(
    vendor, 'get', ax=axs[0], bar_colours=bar_colours, sanity_checks=False, ncols=1, loc=2
)
axs[0].set_xlabel('Nodes (N) and threads-per-node (T)')

axs[1].set_title('Write (PUT requests)')
_, df_put = plot_single_vendor_summary(vendor, 'put', ax=axs[1], bar_colours=bar_colours, legend=False)
axs[1].set_xlabel('Nodes (N) and threads-per-node (T)')

display(pd.concat([df_get, df_put]))
fig.tight_layout()
fig.savefig(f'figures/{vendor}-throughput.png')
# Out:
#                    single-node single-thread (GiB/s)  \
# Maximum GET score                           0.465791
# Maximum PUT score                           0.260723
#
#                    single-node multi-thread (GiB/s)  \
# Maximum GET score                          5.754814
# Maximum PUT score                          2.868115
#
#                    multi-node multi-thread (GiB/s)
# Maximum GET score                        15.681504
# Maximum PUT score                         4.323301

# %% [markdown]
# Object count throughput:

# %%
# Code 

vendor = 'pure'
fig, axs = plt.subplots(figsize=(7, 6), nrows=2)
# fig.suptitle(f'{vendor} benchmark results'.upper())
bar_colours = {"10KiB":"blue", "10MiB":"indigo", "100MiB":"slateblue", "1GiB":"mediumvioletred"}
axs[0].set_title('Read (GET requests)')
_, df_get = plot_single_vendor_summary(
    vendor, 'get', unit='kIOPS', ax=axs[0], bar_colours=bar_colours, 
    sanity_checks=False, ncols=4,
)
axs[0].set_xlabel('Nodes (N) and threads-per-node (T)')
axs[0].set_yscale('log')
ymin, ymax = axs[0].get_ylim()
axs[0].set_ylim((ymin, 50*ymax))

axs[1].set_title('Write (PUT requests)')
_, df_put = plot_single_vendor_summary(
    vendor, 'put', unit='kIOPS', ax=axs[1], bar_colours=bar_colours, legend=False
)
axs[1].set_xlabel('Nodes (N) and threads-per-node (T)')
axs[1].set_yscale('log')
fig.tight_layout()

display(pd.concat([df_get, df_put]))
plt.savefig(f'figures/{vendor}-iops.png')
# Out:
#                    single-node single-thread (kIOPS)  \
# Maximum GET score                            1.88587
# Maximum PUT score                            0.67168
#
#                    single-node multi-thread (kIOPS)  \
# Maximum GET score                          84.32127
# Maximum PUT score                          21.54101
#
#                    multi-node multi-thread (kIOPS)
# Maximum GET score                        204.49645
# Maximum PUT score                         42.85901

# %% [markdown]
# ### Quobyte
#
# File size throughput:

# %%
# Code 
vendor = 'quobyte'
fig, axs = plt.subplots(figsize=(7, 6), nrows=2)
bar_colours = {"10KiB":"blue", "10MiB":"indigo", "100MiB":"slateblue", "1GiB":"mediumvioletred"}

axs[0].set_title('Read (GET requests)')
_, df_get = plot_single_vendor_summary(
    vendor, 'get', ax=axs[0], bar_colours=bar_colours, sanity_checks=True, legend=False,
)
axs[0].set_xlabel('Nodes (N) and threads-per-node (T)')

axs[1].set_title('Write (PUT requests)')
_, df_put = plot_single_vendor_summary(
    vendor, 'put', ax=axs[1], bar_colours=bar_colours, legend=True, ncols=3
)
axs[1].set_xlabel('Nodes (N) and threads-per-node (T)')

display(pd.concat([df_get, df_put], axis=0))

fig.tight_layout()
fig.savefig(f'figures/{vendor}-throughput.png')
# Out:
# WARNING:root:[Errno 2] No such file or directory: 'benchmark-runs/summaries/../raw-data/s3-full.quobyte-get-2-50-1GiB-5000-300s.csv.zst'
# WARNING:root:No useable analysis time window for PUT requests (some threads completed only 1 request)
#  File: benchmark-runs/summaries/../raw-data/s3-full.quobyte-get-2-100-1GiB-5000-300s.csv.zst
# WARNING:root:No useable analysis time window for GET requests (some threads completed only 1 request)
#  File: benchmark-runs/summaries/../raw-data/s3-full.quobyte-get-5-20-1GiB-1000-60s.csv.zst
# WARNING:root:No useable analysis time window for PUT requests (some threads completed only 1 request)
#  File: benchmark-runs/summaries/../raw-data/s3-full.quobyte-get-5-50-1GiB-1000-60s.csv.zst
# WARNING:root:No useable analysis time window for GET requests (some threads completed only 1 request)
#  File: benchmark-runs/summaries/../raw-data/s3-full.quobyte-get-5-50-1GiB-1000-60s.csv.zst
# ...

# %% [markdown]
# Object count throughput:

# %%
# Code 

vendor = 'quobyte'
fig, axs = plt.subplots(figsize=(7, 6), nrows=2)
# fig.suptitle(f'{vendor} benchmark results'.upper())
bar_colours = {"10KiB":"blue", "10MiB":"indigo", "100MiB":"slateblue", "1GiB":"mediumvioletred"}
axs[0].set_title('Read (GET requests)')
_, df_get = plot_single_vendor_summary(
    vendor, 'get', unit='kIOPS', ax=axs[0], bar_colours=bar_colours, 
    sanity_checks=False, ncols=5,
)
axs[0].set_xlabel('Nodes (N) and threads-per-node (T)')
axs[0].set_yscale('log')
ymin, ymax = axs[0].get_ylim()
axs[0].set_ylim((ymin, 20*ymax))

axs[1].set_title('Write (PUT requests)')
_, df_put = plot_single_vendor_summary(vendor, 'put', unit='kIOPS', ax=axs[1], bar_colours=bar_colours, legend=False)
axs[1].set_xlabel('Nodes (N) and threads-per-node (T)')
axs[1].set_yscale('log')
fig.tight_layout()

display(pd.concat([df_get, df_put]))
plt.savefig(f'figures/{vendor}-iops.png')
# Out:
#                    single-node single-thread (kIOPS)  \
# Maximum GET score                            0.11115
# Maximum PUT score                            0.06046
#
#                    single-node multi-thread (kIOPS)  \
# Maximum GET score                           3.07966
# Maximum PUT score                           0.74991
#
#                    multi-node multi-thread (kIOPS)
# Maximum GET score                          5.06794
# Maximum PUT score                          1.12521

# %% [markdown]
# ### Caringo
#
# File size throughput:

# %%
# Code 
vendor = 'caringo'
fig, axs = plt.subplots(figsize=(7, 6), nrows=2)
# fig.suptitle(f'{vendor} benchmark results'.upper())
bar_colours = {"10KiB":"blue", "10MiB":"indigo", "100MiB":"slateblue", "1GiB":"mediumvioletred"}
axs[0].set_title('Read (GET requests)')
_, df_get = plot_single_vendor_summary(
    vendor, 'get', ax=axs[0], bar_colours=bar_colours, sanity_checks=True, ncols=1
)
axs[0].set_xlabel('Nodes (N) and threads-per-node (T)')

axs[1].set_title('Write (PUT requests)')
_, df_put = plot_single_vendor_summary(vendor, 'put', ax=axs[1], bar_colours=bar_colours, legend=False)
axs[1].set_xlabel('Nodes (N) and threads-per-node (T)')

display(pd.concat([df_get, df_put]))
fig.tight_layout()
fig.savefig(f'figures/{vendor}-throughput.png')
# Out:
# WARNING:root:No useable analysis time window for GET requests (some threads completed only 1 request)
#  File: benchmark-runs/summaries/../raw-data/s3-full.caringo-get-5-100-1GiB-5000-300s.csv.zst
#                    single-node single-thread (GiB/s)  \
# Maximum GET score                           0.103877
# Maximum PUT score                           0.025654
#
#                    single-node multi-thread (GiB/s)  \
# Maximum GET score                          3.524268
# Maximum PUT score                          1.490791
#
#                    multi-node multi-thread (GiB/s)
# Maximum GET score                         6.656924
# Maximum PUT score                         2.538105

# %% [markdown]
# Object count throughput:

# %%
# Code 

vendor = 'caringo'
fig, axs = plt.subplots(figsize=(7, 6), nrows=2)
# fig.suptitle(f'{vendor} benchmark results'.upper())
bar_colours = {"10KiB":"blue", "10MiB":"indigo", "100MiB":"slateblue", "1GiB":"mediumvioletred"}
axs[0].set_title('Read (GET requests)')
_, df_get = plot_single_vendor_summary(
    vendor, 'get', unit='kIOPS', ax=axs[0], bar_colours=bar_colours, 
    sanity_checks=False, ncols=5,
)
axs[0].set_xlabel('Nodes (N) and threads-per-node (T)')
axs[0].set_yscale('log')
ymin, ymax = axs[0].get_ylim()
axs[0].set_ylim((ymin, 50*ymax))

axs[1].set_title('Write (PUT requests)')
_, df_put = plot_single_vendor_summary(
    vendor, 'put', unit='kIOPS', ax=axs[1], bar_colours=bar_colours, legend=False
)
axs[1].set_xlabel('Nodes (N) and threads-per-node (T)')
axs[1].set_yscale('log')

display(pd.concat([df_get, df_put]))
fig.tight_layout()
plt.savefig(f'figures/{vendor}-iops.png')
# Out:
#                    single-node single-thread (kIOPS)  \
# Maximum GET score                            0.05501
# Maximum PUT score                            0.00873
#
#                    single-node multi-thread (kIOPS)  \
# Maximum GET score                           4.09969
# Maximum PUT score                           0.56737
#
#                    multi-node multi-thread (kIOPS)
# Maximum GET score                          7.79303
# Maximum PUT score                          0.88572

# %% [markdown]
# ## Vendor comparison plots

# %%
# Code - function defs 

def plot_vendor_comparison(
    obj_size, 
    unit='GiB/s',
    figsize=(7, 5),
    bar_colours={'pure':'r', 'quobyte':'b', 'caringo':'g'},
    highlight_missing=True,
    legend=True,
    **legend_kwargs,
):
    
    # Load scores
    data_dir = pathlib.Path('./benchmark-runs/summaries/txt/')
    scores = {}
#     for nodes in [1, 5]:
#         for threads in [1, 100]:
    for nodes, threads in [(1, 1), (1, 100), (2, 100), (5, 100)]:
            
            # Top level key for different plots
            ax_key = f'{nodes}-Node'
            if nodes != 1:
                ax_key += 's'
            ax_key += f' {threads}-Thread'
            if threads != 1:
                ax_key += 's'
            scores[ax_key] = {}
            
            for op in ['get', 'put']:
                # Per-axis key for each bar group
                group_key = 'Read' if op == 'get' else 'Write'
                scores[ax_key][group_key] = {}
                for vendor in ['pure', 'quobyte', 'caringo']:
                    # Always use 'get' as op filter since this file also holds 'put' scores
                    files = list(filter(
                        lambda f: file_filter(f, vendor, 'get', nodes, threads, obj_size),
                        data_dir.iterdir()
                    ))
                    # Sanity check
                    if len(files) > 1:
                        raise Exception(
                            f'Ambiguous file filter - {len(files)} files found for:',
                            vendor, 'get', nodes, threads, obj_size,
                            '\nFiles:', files
                        )
                    try:
                        # Read scores from text file
                        scores[ax_key][group_key][vendor] = parse_text_summary(files[0])[op.upper()]
                    except Exception:
                        # If no-data then use 0 as placeholder
#                         print('Missing data for', nodes, threads, op, vendor)
                        scores[ax_key][group_key][vendor] = {'GiB/s': 0, 'kIOPS': 0}
                    if unit not in scores[ax_key][group_key][vendor].keys():
                        scores[ax_key][group_key][vendor] = {unit: 0}                    
#     print(scores)

    fig, axs = plt.subplots(figsize=figsize, ncols=2, nrows=len(list(scores.keys()))//2)
    for ax, (ax_key, scores_subset) in zip(axs.flatten(), scores.items()):

        # Wrangle data into plottable format
        groups = list(scores_subset.keys())
        keys = [k for k, v in scores_subset[groups[0]].items() if unit in v.keys()]
        data = {k:[scores_subset[g][k][unit] for g in groups] for k in keys}

        x = np.arange(len(groups))  # the label locations
        width = 1 / (1+len(keys)) # the width of the bars
        multiplier = (1.5 - len(keys)/2)

        if ax is None:
            fig, ax = plt.subplots(figsize=(8, 4), constrained_layout=True)
        ax.grid(axis="y", lw=0.5, zorder=0)

        missing_label_set = False
        for i, (k, scores) in enumerate(data.items()):
            offset = width * multiplier
            rects = ax.bar(
                x + offset, 
                scores, 
                width, 
                ec="k", 
                label=k, 
                zorder=3,
                color=(bar_colours[k] if bar_colours is not None else None)
            )
            multiplier += 1

            # Add temporary marker for missing data
            if highlight_missing:
                for i, s in enumerate(scores):
                    if s == 0:
                        L = 'Missing data' if not missing_label_set else ''
                        ax.axvline([i+offset], lw=5, c='grey', alpha=0.5, label=L)
                        missing_label_set = True


        # Add some extra stuff
        ax.set_xticks(x + width, groups)
        ax.set_ylabel(unit)
        ax.set_title(ax_key)
        if legend:
            ax.legend(title='Object store:', **legend_kwargs)
        
    fig.tight_layout()
#     fig.subplots_adjust(wspace=0.5)
    return fig, axs

# %%
# Code 
obj_size = '1GiB'
fig, axs = plot_vendor_comparison(obj_size)
fig.suptitle(f'Large objects comparison ({obj_size})', y=1.05)
fig.savefig('figures/vendor-comparison-large-obj.png', bbox_inches='tight')
fig.show()
# Out:
# /var/folders/q4/76wx8f413nb6_5zh09x8312r0000gn/T/ipykernel_3759/627036424.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# Object 'create' comparison:

# %%
# Code 
obj_size = '10KiB'
fig, axs = plot_vendor_comparison(obj_size, unit='kIOPS')
fig.suptitle(f"Object 'create' comparison", y=1.05)
for ax in axs.flatten():
    ax.set_yscale('log')
fig.savefig('figures/vendor-comparison-create.png', bbox_inches='tight')
fig.show()
# Out:
# /var/folders/q4/76wx8f413nb6_5zh09x8312r0000gn/T/ipykernel_3759/4030385511.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Missing Quobyte data investigation
#
# From the very first Quobyte results plot above (reproduced below for convenience) we can see that there is some missing data for the large 1GiB object sizes. It turns out that the reason for this missing data is actually quite interesting, as will be explained in this section.

# %%
# Code 
fig, ax = plt.subplots(figsize=(8, 3))
bar_colours = {"10KiB":"blue", "10MiB":"indigo", "100MiB":"slateblue", "1GiB":"mediumvioletred"}
plot_single_vendor_summary('quobyte', 'put', ax=ax, bar_colours=bar_colours)
fig.tight_layout()

# %% [markdown]
# To understand why this data is missing, we first need to highlight exactly how the `warp` tool runs its post-processing data analysis to produce average throughput scores. As [stated in the warp docs](https://github.com/minio/warp#analysis-data), the analysis process purposefully excludes any 'warm-up' or 'cool-down' sections of benchmark window. It does this by *only* using requests which start *after all threads have completed at least 1 full request* and also ignores requests which occur after any single thread has started it's final request of the benchmark run.
#
# This idea is illustrated graphically in the toy example below, which shows time span for each individual request to the storage API as a red/green/blue horizontal line with the black dots highlighting the points at which one request completes and new request starts. In this example, the analysis window starts as soon as thread 1 has completed its first request (since it's the slowest to complete it's first one) and ends as soon as thread 3 starts its final request (since it's the first to start its final one).

# %%
# Code 

from cycler import cycler
custom_colour_cycler = cycler(color=['r', 'g', 'b'])

df, cmd = load_raw_data(
    'benchmark-runs/raw-data/s3-full.quobyte-get-5-50-1GiB-1000-60s.csv.zst', 
    sanity_checks=False,
)
df = df[(df.op == 'PUT') & (df.thread < 10)]

window_start = df.groupby('thread').end.first().max().timestamp()
window_end = df.groupby('thread').start.last().min().timestamp()

fig, ax = plt.subplots(figsize=(8, 3))
ax.set_prop_cycle(custom_colour_cycler)
ax.set_ylabel('Thread ID')
ax.set_xlabel('Time')
for thread, requests in df.groupby('thread')[['start', 'end']]:
    for n, r in requests.iterrows():
        ax.plot([r.start.timestamp(), r.end.timestamp()], [thread+1, thread+1], lw=2, ls='-', zorder=-1)        
        ax.scatter([r.start.timestamp(), r.end.timestamp()], [thread+1, thread+1], s=50, c='k')       
ax.axvline([window_start], ls="--", c='grey', lw=2, label="Start of analysis window")
ax.axvline([window_end], ls="--", c='k', lw=2, label="End of analysis window")
ax.set_yticks(range(1, 11))
ax.legend(framealpha=1)
plt.show()

# %% [markdown]
# This procedure used by `warp` for choosing an appropriate analysis time window makes sense since it only selects the times where all clients/threads are truely acting concurrently and ignores any start-up time for individual clients/threads.
#
# ### Exceptionally slow requests
#
# With this explanation of the internal warp workings in mind, we can now explain why the 5-node-50-thread-1-GiB data is missing from the Quobyte PUT request plot. If we look at the distribution of durations for individual API requests for each thread ('thread' ID here is an amalgamation of node & thread, so thread 51, for example, is the 1st thread on node 2) we get the following:

# %%
# Code 
print('Request duration statistics (in seconds) by thread:')
df, cmd = load_raw_data('benchmark-runs/raw-data/s3-full.quobyte-get-5-50-1GiB-1000-60s.csv.zst')
df = df[(df.op == 'PUT')]
df['duration'] = df.duration_ns / 1e9
(df.groupby('thread')
 .duration
 .describe()
 .sort_values('max')
)
# Out:
# WARNING:root:No useable analysis time window for PUT requests (some threads completed only 1 request)
#  File: benchmark-runs/raw-data/s3-full.quobyte-get-5-50-1GiB-1000-60s.csv.zst
# WARNING:root:No useable analysis time window for GET requests (some threads completed only 1 request)
#  File: benchmark-runs/raw-data/s3-full.quobyte-get-5-50-1GiB-1000-60s.csv.zst
# Request duration statistics (in seconds) by thread:
#         count         mean        std          min          25%          50%  \
# thread
# 105.0     5.0    62.923060  16.105356    43.227406    52.954744    60.870009
# 149.0     5.0    77.690206   9.985521    65.505663    69.811569    78.787877
# 84.0      5.0    72.346408  15.787528    52.373975    65.814152    66.584394
# 74.0      5.0    76.105024  17.291862    48.843390    69.110789    84.670188
# 167.0     7.0    57.169766  25.879192    25.945377    35.369773    62.094809
# ...       ...          ...        ...          ...          ...          ...
# ...

# %% [markdown]
# The above table has been sorted by the 'max' column which is the maximum time (in seconds) taken for a single PUT request to complete on the corresponding thread. This reveals that there are a handful of threads which take an extremely long time to complete a single request (\~100 minutes), relative to the mean request duration on the quicker threads (\~1 minute).
#
# We can confirm that this is not a specific issue with a single node if we group by node instead of thread, where we see that each node has at least 1 of these extremely slow operations:

# %%
# Code 
df, cmd = load_raw_data('benchmark-runs/raw-data/s3-full.quobyte-get-5-50-1GiB-1000-60s.csv.zst')
df = df[(df.op == 'PUT')]
df['duration'] = df.duration_ns / 1e9
df.groupby('client_id').duration.describe().sort_values('max')
# Out:
# WARNING:root:No useable analysis time window for PUT requests (some threads completed only 1 request)
#  File: benchmark-runs/raw-data/s3-full.quobyte-get-5-50-1GiB-1000-60s.csv.zst
# WARNING:root:No useable analysis time window for GET requests (some threads completed only 1 request)
#  File: benchmark-runs/raw-data/s3-full.quobyte-get-5-50-1GiB-1000-60s.csv.zst
#            count        mean         std        min        25%        50%  \
# client_id
# 3eO5Sm     200.0  133.602255  415.507606  30.166164  62.066074  84.353223
# sPvvwx     200.0  157.947584  584.750055  28.967650  62.355935  84.426418
# OQb49P     200.0  154.740682  587.038511  30.749461  61.440007  83.091980
# vn8PoT     200.0  218.740424  836.254864  25.945377  61.840554  84.968355
# k10D3I     200.0  198.331811  722.148550  30.137883  63.912826  85.447682
#
#                   75%          max
# client_id
# 3eO5Sm     128.425745  5917.840378
# sPvvwx     115.738256  6002.459882
# ...

# %% [markdown]
# The reason this results in warp analysis procedure failing to produce a calculated throughput is clear if we consider the usable time window for such a run containing a handful of extremely slow requests. Using the same plot format as above (without the black dots for clarity) we see that the *start* of the analysis window (as defined by warp) is actually **after** the *end* of the window. Hence the window size is effectively zero so there are no valid requests within the analysis window. Unfortunately, warp simply reports this result as 'too few samples' in the analysis window which is not particularly helpful...

# %%
# Code 

from cycler import cycler
custom_colour_cycler = cycler(color=['r', 'g', 'b'])

df, cmd = load_raw_data('benchmark-runs/raw-data/s3-full.quobyte-get-5-50-1GiB-1000-60s.csv.zst')
df = df[(df.op == 'PUT')]

window_start = df.groupby('thread').end.first().max().timestamp()
window_end = df.groupby('thread').start.last().min().timestamp()

fig, ax = plt.subplots(figsize=(8, 8))
ax.set_prop_cycle(custom_colour_cycler)
ax.set_ylabel('Thread ID')
ax.set_xlabel('Time')
for thread, requests in df.groupby('thread')[['start', 'end']]:
    for n, r in requests.iterrows():
        ax.plot([r.start.timestamp(), r.end.timestamp()], [thread+1, thread+1], lw=2, ls='-', zorder=-1)        
ax.axvline([window_start], ls="--", c='grey', lw=3, label="Start of analysis window")
ax.axvline([window_end], ls="--", c='k', lw=3, label="End of analysis window")
ax.legend(framealpha=1)
plt.show()
# Out:
# WARNING:root:No useable analysis time window for PUT requests (some threads completed only 1 request)
#  File: benchmark-runs/raw-data/s3-full.quobyte-get-5-50-1GiB-1000-60s.csv.zst
# WARNING:root:No useable analysis time window for GET requests (some threads completed only 1 request)
#  File: benchmark-runs/raw-data/s3-full.quobyte-get-5-50-1GiB-1000-60s.csv.zst

# %% [markdown]
# The simplest way to solve this is issue directly is to just increase the volume of data uploaded so that all threads remain busy for the full duration of any particularly slow upload occuring simultaneously on other threads; however, this could quickly lead to capacity issues on systems with limited storage.
#
# By looking at the tables below we can see that this is also the reason for the other missing data:

# %%
# Code 
n, t = 5, 100
print(f'{n}-nodes-{t}-threads-1GiB:\n')
print('Request duration statistics (in seconds) by thread:')
df, cmd = load_raw_data(f'benchmark-runs/raw-data/s3-full.quobyte-get-{n}-{t}-1GiB-5000-300s.csv.zst')
df = df[(df.op == 'PUT')]
df['duration'] = df.duration_ns / 1e9
(df.groupby('thread')
 .duration
 .describe()
 .sort_values('max')
)
# Out:
# WARNING:root:No useable analysis time window for PUT requests (some threads completed only 1 request)
#  File: benchmark-runs/raw-data/s3-full.quobyte-get-5-100-1GiB-5000-300s.csv.zst
# WARNING:root:Benchmark data for PUT requests only contains 100 threads, expected 500.
#  File: benchmark-runs/raw-data/s3-full.quobyte-get-5-100-1GiB-5000-300s.csv.zst
# WARNING:root:No useable analysis time window for GET requests
#  File: benchmark-runs/raw-data/s3-full.quobyte-get-5-100-1GiB-5000-300s.csv.zst
# WARNING:root:Benchmark data for GET requests only contains 100 threads, expected 500.
#  File: benchmark-runs/raw-data/s3-full.quobyte-get-5-100-1GiB-5000-300s.csv.zst
# 5-nodes-100-threads-1GiB:
#
# Request duration statistics (in seconds) by thread:
#         count          mean          std           min           25%  \
# thread
# 37.0     14.0    346.798769   100.830331    177.732333    293.694731
# 21.0     15.0    334.271633    94.681025    172.863544    271.633777
# ...

# %%
# Code 
n, t = 2, 100
print(f'{n}-nodes-{t}-threads-1GiB:\n')
print('Request duration statistics (in seconds) by thread:')
df, cmd = load_raw_data(f'benchmark-runs/raw-data/s3-full.quobyte-get-{n}-{t}-1GiB-5000-300s.csv.zst')
df = df[(df.op == 'PUT')]
df['duration'] = df.duration_ns / 1e9
(df.groupby('thread')
 .duration
 .describe()
 .sort_values('max')
)
# Out:
# WARNING:root:No useable analysis time window for PUT requests (some threads completed only 1 request)
#  File: benchmark-runs/raw-data/s3-full.quobyte-get-2-100-1GiB-5000-300s.csv.zst
# 2-nodes-100-threads-1GiB:
#
# Request duration statistics (in seconds) by thread:
#         count          mean          std           min           25%  \
# thread
# 91.0     34.0    107.411613    45.166146     33.658978     74.320470
# 147.0    32.0    124.495937    55.905320     33.285548     91.290427
# 184.0    32.0    119.534297    60.613609     33.276262     60.682333
# 88.0     29.0    128.860517    54.791533     42.454060     99.049018
# 132.0    34.0    114.944437    61.545355     42.697609     55.923035
# ...       ...           ...          ...           ...           ...
# 71.0      3.0   3606.086906  6120.597235     71.796104     72.358460
# 134.0     2.0   5389.548321  7510.307109     78.959236   2734.253779
# 23.0      2.0   5390.638673  7520.509277     72.835565   2731.737119
# ...
